# %%
import pandas as pd
import json
import requests
import os
from pandas import json_normalize
from passlib.context import CryptContext
from dotenv import find_dotenv, load_dotenv
env_loc = find_dotenv('.env')
load_dotenv(env_loc)
# Out:
# True

# %%
api_key = os.environ.get('AIRTABLE_API_KEY')
user_table_url = 'https://api.airtable.com/v0/appe7KAdke2PXikpW/Users'
authorization_header = {'Authorization':f'Bearer {api_key}',
                        'Content-Type': 'application/json'}

def create_user(username: str, password: str):
    hashed_password = create_password_hash(password)
    created_date = datetime.now().strftime('%m-%d-%Y')
    payload = {'fields':{'username':username,
                    'hashed_password':hashed_password,
                    'created_date':created_date,
                    'last_login':created_date}
        }
    response = requests.post(user_table_url, headers=authorization_header, data=json.dumps(payload))
    return response.json()

# %%
create_user('emma','testing')
# Out:
# {'id': 'recUoiwSSpfdW9bHy',
#  'fields': {'username': 'emma',
#   'hashed_password': '$2b$12$7Joq1P46cgZOhDC5gRSVNOyC/f0TesLED/lEZAa39UfCcCZABcRPC',
#   'created_date': '04-20-2021',
#   'last_login': '04-20-2021'},
#  'createdTime': '2021-04-20T17:02:15.000Z'}

# %%
def get_all_users():
    url = f'https://api.airtable.com/v0/appe7KAdke2PXikpW/Users'
    headers = {'Authorization': f'Bearer {api_key}'}
    response = requests.get(url, headers=headers).json()
    user_list = []
    for record in response['records']:
        fields = record['fields']
        fields['id'] = record['id']
        user_list.append(fields)
    df = json_normalize(user_list)
    return df

# %%
df = get_all_users()

# %%
df
# Out:
#    last_login                          username created_date password_raw  \
# 0  20-04-2021  sophie.clark@fierarealestate.com   20-04-2021  hello-world
# 1  04-20-2021                              emma   04-20-2021          NaN
# 2  20-04-2021  david.bender@fierarealestate.com   20-04-2021     password
#
#                                      hashed_password                 id
# 0  $2b$12$HSwxMVcBJkRIIpQEya1jTO2fakQW9cBbhOA8DSA...  recNkyb2PMKUqr13T
# 1  $2b$12$7Joq1P46cgZOhDC5gRSVNOyC/f0TesLED/lEZAa...  recUoiwSSpfdW9bHy
# 2  $2b$12$rUqaGnZYLvzFKnextdu6su9JrQYRaa2cRMHI7p0...  recWfC6qz9hTIeK0O

# %%
pwd_context = CryptContext(schemes=["bcrypt"], deprecated="auto")

# %%
def create_password_hash(password):
    return pwd_context.hash(password)

def verify_password(plain_password, password_hash):
    return pwd_context.verify(plain_password, password_hash)

# %%
hash = create_password_hash('hello-world')

# %%
hash
# Out:
# '$2b$12$HSwxMVcBJkRIIpQEya1jTO2fakQW9cBbhOA8DSAzyhA/7JNlQwC/S'

# %%
verify_password('hello-world',hash)
# Out:
# True

# %%
api_key = os.environ.get('AIRTABLE_API_KEY')
user_base = 'appe7KAdke2PXikpW'
projects_base = 'app6kSWgnKx3E5ULh'

def get_all_users(api_key: str = api_key):
    url = f'https://api.airtable.com/v0/appe7KAdke2PXikpW/Users'
    headers = {'Authorization': f'Bearer {api_key}'}
    response = requests.get(url, headers=headers).json()
    user_list = []
    for record in response['records']:
        fields = record['fields']
        user_list.append(fields)
    df = json_normalize(user_list)
    return df

# %%
def get_current_user(username: str, api_key: str = api_key):
    user_df = get_all_users(api_key)
    user = user_df[user_df.username == username]
    if len(user) == 0:
        print('Username either does not exist or is misspelled.')
        return False
    else:
        return json.loads(user.to_json(orient='records'))[0]

# %%
datetime.now().strftime('%m-%d-%Y')
# Out:
# '04-20-2021'

# %%
import secrets
f'key{secrets.token_urlsafe(15)}'
# Out:
# 'keyfL03sW-OwXhZsNnWasZH'

# %%
from typing import Optional
from datetime import datetime, timedelta
from jose import JWTError, jwt
def create_access_token(data: dict, expires_delta: Optional[timedelta] = None):
    to_encode = data.copy()
    if expires_delta:
        expire = datetime.utcnow() + expires_delta
    else:
        expire = datetime.utcnow() + timedelta(minutes=15)
    to_encode.update({"exp": expire})
    encoded_jwt = jwt.encode(to_encode, 'hello-world', algorithm='HS256')
    return encoded_jwt

# %%
create_access_token({'sub':'david.bender@fierarealestate.com'})
# Out:
# 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJkYXZpZC5iZW5kZXJAZmllcmFyZWFsZXN0YXRlLmNvbSIsImV4cCI6MTYxODkzMzc3OX0.6fwkFSjYJGhlh5OJLMamIppTAQWH6elOyIBTo86EeHI'

# %%
def authenticate_user(username, password):
    # First, retrieve the user by the email provided
    user = get_user(username)
    if not user:
        return False
    
    # If present, verify password against password hash in database
    password_hash = user['hashed_password']
    username = user['username']
    
    if not verify_password(password, password_hash):
        return False
    return user

# %%
user = authenticate_user('david.bender@fierarealestate.com','password')

# %%
user['hashed_password']
# Out:
# '$2b$12$rUqaGnZYLvzFKnextdu6su9JrQYRaa2cRMHI7p0/1/8C6xBZboJ2G'

# %%
check_password('david.bender@fierarealestate.com', 'helo-world')
# Out:
# 'Password INCORRECT'

# %%
users
# Out:
#                            username password_hash created_date  last_login
# 0  sophie.clark@fierarealestate.com   hello-world   20-04-2021  20-04-2021
# 1  david.bender@fierarealestate.com   hello-world   20-04-2021  20-04-2021

# %%
json_normalize(userList)
# Out:
#                            username password_hash created_date  last_login
# 0  sophie.clark@fierarealestate.com   hello-world   20-04-2021  20-04-2021
# 1  david.bender@fierarealestate.com   hello-world   20-04-2021  20-04-2021

# %%
test = airtable_call('Valuations',api_key, projects_base)
offset = test['offset']
test2 = airtable_call('Valuations',api_key, projects_base, offset=offset)

# %%
def airtable_iterate(table_name: str, api_key: str, base_id: str):
    payload = {}
    offset = ''
    while True:
        try:
            response = airtable_call(table_name, api_key, base_id, offset)
            if not response
# Out:
# {'records': [{'id': 'rec03byi2QOz3FfvA',
#    'fields': {'Asset': ['recRqzzL0lr3lzVYw'],
#     'Market Value': 6370000,
#     'Date Completed': '2019-12-31',
#     'Valuer': 'CBRE',
#     'Notes': 'Shared Documents/Shared Data/Palmer Capital Partners/Valuations - Core/FRELIF/PCIF - Draft Valuation Q4 2019 v3 (incl. Stockport)',
#     'Name': 'Newcastle Upon Tyne (West Denton Retail Park), 12-2019: £6370000',
#     'Most Recent Valuation Date': ['2021-03-31'],
#     'Most Recent': 0,
#     'Most Recent Market Value': 0,
#     'Asset Funding Source': ['recHw9u9srpzErpZr'],
#     'Created Date': '2020-01-28',
#     'Asset Status': ['Owned']},
#    'createdTime': '2020-01-28T13:48:39.000Z'},
#   {'id': 'rec058jKwGKnXoGug',
#    'fields': {'Asset': ['recPZ5AhANATf2mSg'],
#     'Market Value': 13900000,
#     'Date Completed': '2019-12-31',
#     'Valuer': 'CBRE',
# ...

# %%
offset2 = test2['offset']
test3 = airtable_call('Valuations',api_key, projects_base, offset=offset2)

# %%
test3['offset']
# Out:
# 'itrDKYzXC89PLbeaf/recWNbdyv2liPbz88'
